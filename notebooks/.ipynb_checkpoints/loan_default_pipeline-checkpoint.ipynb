# %% [markdown]
# # Loan Default Prediction — Local Demo (LocalStack)
# This notebook demonstrates EDA, preprocessing and training using a local MLflow server.

# %% [markdown]
# **Environment:** Activate your conda env `snow` in Command Prompt (cmd.exe) before running.

# %%
# %%bash
# Optional: extract uploaded dataset
if [ -f /mnt/data/Loan\ Default\ Prediction-selected.zip ]; then
  unzip -o /mnt/data/Loan\ Default\ Prediction-selected.zip -d data/raw/
  echo 'extracted'
else
  echo 'Please place dataset zip at /mnt/data/Loan Default Prediction-selected.zip'
fi

# %%
import pandas as pd
import os

print('MLflow URI:', os.getenv('MLFLOW_TRACKING_URI', 'http://localhost:5000'))

# Preview processed data if exists
p = 'data/processed/loan.csv'
if os.path.exists(p):
    display(pd.read_csv(p).head())
else:
    print('Processed CSV not found at', p)

# %%
# Placeholder: run the prepare script
# !python src/data/prepare.py

# %%
# Placeholder: train the model and log to MLflow
# !python src/models/train.py
